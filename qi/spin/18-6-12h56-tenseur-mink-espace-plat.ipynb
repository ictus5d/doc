# %%
# %display latex

# %% [markdown]
# https://fr.wikipedia.org/wiki/%C3%89quation_d%27Einstein
#
# Dans le cas où une région de l'espace est vide (c'est-à-dire que le tenseur énergie-impulsion $T_{ab}$ est nul), l'équation d'Einstein s'écrit $R_{\mu \nu }=0$.
#
# ![image.png](attachment:image.png)

# %%
var("c n_0 c_0 V")
# Out:
# (c, n_0, c_0, V)

# %%
c0=c==(c_0/n_0+1-(1/n_0^2))*V;c0
# Out:
# c == V*(c_0/n_0 - 1/n_0^2 + 1)

# %%
solve(c==(c_0/n_0+1-(1/n_0^2))*V,c)
# Out:
# [c == (V*c_0*n_0 + V*n_0^2 - V)/n_0^2]

# %%
solve(c==(c_0/n_0+1-(1/n_0^2))*V,V)
# Out:
# [V == c*n_0^2/(c_0*n_0 + n_0^2 - 1)]

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Cette figure montre la définition du radian physique, avec mon équation $ç=314159265$ et $c=299792458$

# %%
deg(x)=x*180/n(pi);show("1 rad =",deg(1)," degres")
# Out:
# '1 rad =' 57.2957795130823 ' degres'

# %%
Cc=314159265;c=299792458
rad(x)=x*n(pi)/180;show(deg(1)," degres = ",
                        round(rad(deg(1)))," rad/s ")
# Out:
# 57.2957795130823 ' degres = ' 1 ' rad/s '

# %%
Cc=314159265.0;c=299792458
deg(x)=x*180/n(pi);show("difference v/c =",deg(Cc/c)," degres")
# Out:
# 'difference v/c =' 60.0415370670599 ' degres'

# %%
Cc/c
# Out:
# 1.04792250977841

# %%
rad(x)=x*n(pi)/180;show(rad(60)," rad/s ")
# Out:
# 1.04719755119660 ' rad/s '

# %%
299792458*1.04719755119660
# Out:
# 3.13941927884810e8

# %%
(314159265.3/1.04719755119660)-299792458# 207km/s
# Out:
# 207541.943678260

# %% [markdown]
# Le coulomb est proche de 1 million de tonnes.
#
# La fréquence angulaire est 0.500000000

# %%
fr=n(314159265.3/(2*pi));round(fr)
# Out:
# 50000000

# %%
fc=n(299792458/(2*pi));round(fc)
# Out:
# 47713452

# %%
beta=fr/fc;beta # indice du vide de l'onde
# Out:
# 1.04792251077911

# %%
c=2*n(pi);c
# Out:
# 6.28318530717959

# %%
L=c/2;L
# Out:
# 3.14159265358979

# %%
h=2*n(pi);h
# Out:
# 6.28318530717959

# %%
hb=h/(2*n(pi));hb # hb*2 facteur de Landé =2
# Out:
# 1.00000000000000

# %%
hb*2*n(pi) #h=2*n(pi) hb=h/2*pi
# Out:
# 6.28318530717959
