# %% [markdown]
# ![image.png](attachment:image.png)
#
# http://kirsch.free.fr/Archeoastronomie_imprime.html#chine

# %%
print "al =", round(10E13), " kms =10 Peta/ms"
# Out:
# al = 100000000000000  kms =10 Peta/ms

# %%
al=10E13;al^2
# Out:
# 1.00000000000000e28

# %% [markdown]
# 1 parsec =3.26 al

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
2^3,3^2
# Out:
# (8, 9)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
