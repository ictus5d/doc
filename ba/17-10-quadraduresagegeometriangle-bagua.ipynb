# %% [markdown]
# An de grâce 2017, 22 août 8:28
# Quadrature du cercle
#
# http://www.chateau-de-mezerville.org/curiosites-geometriques/quadrature-du-cercle.php
#
# L'académie ayant censuré stupidement toute recherche dans ce domaine, preuve de son inutilité !
#
# http://smf4.emath.fr/Publications/RevueHistoireMath/11/pdf/smf_rhm_11_89-139.pdf

# %% [markdown]
# Modification, après avoir calculé et trouvé la formule qui permet d'avoir une quadrature parfaite malgré l'ignorance des académiciens.
# ###### Première Partie : Construction géométrique du nombre Pi d’après Kochansky
#
# Soit un cercle de centre $B$ et de rayon $BC = 1$ (unité), deux diamètres perpendiculaires $AC$ et $OJ$, deux perpendiculaires en $A$ et $C$ au diamètre $AC$.
#
# Sur la perpendiculaire à $AC$ en $C$, on trace trois segments égaux
#
# $CD = DE = EF = 1 $(unité)
#
# Un arc de cercle de centre $J$, rayon $JB = 1$ (unité), coupe le cercle précédent en $G$ et $K$, déterminant un côté du triangle équilatéral inscrit et par conséquence
#
# un angle $(A B G) = 30^o$
#
# $BG$ prolongé coupe la perpendiculaire en$ A $en $H$.
#
# Le segment $FH$ est égal à $\pi$
#
# ###### Démonstration :
#
# On trace la perpendiculaire $IH$ à $CF$
#
# Dans le triangle $ABH$    tg 30° = $AH/AB= 0,57735$ (AB = 1 unité)
#
# Dans le triangle rectangle $HIF$,   $HI = AC = 2$ unités
#
# $IF = CF – CI et CI = AH =  0.57735$
#
# $HI² +IF² = HF² (IF = 3 – 0.57735)$
#
# $HF² = 4 + (3 – 0.57735)²$
#
# Soit : $HF = \sqrt 9,86923$
#
# $HF = 3,141533$

# %%
from sage.plot.ellipse import Ellipse
a1= arc((1,0), 1, angle=pi, sector=(-1,pi/3), color="blue",
thickness=1, zorder=5);f=(sqrt(1-x^2) );r=2/sqrt(n(pi))
p=plot(f,-1,1,aspect_ratio=1);q=plot(-f,-1,1,aspect_ratio=1)
l=line(((0.0,0),(0.57,1)), color="red",thickness=1)
l1=line(((0.57,0),(0.57,1)), color="red",thickness=1)
l2=line(((0.57,0),(0.57,-1)), color="red",thickness=1)
l3=line(((0,-1),(3,-1)), color="blue",thickness=1)
l4=line(((0.5,0),(0.5,0.87)), color="blue",
linestyle="dashed",thickness=1)
l5=line(((0.5,0),(0.5,-0.87)), color="blue",
linestyle="dashed",thickness=1)
l6=line(((0,1),(2,1)), color="blue",thickness=1)
l7=line(((0.57,1),(3,-1)), color="red",thickness=1)
A = text("A", (-0.1,1.1), color="black", fontsize=14,rotation=0)
B = text("B", (-0.1,-0.1), color="black", fontsize=14,rotation=0)
C = text("C", (-0.1,-1.1), color="black", fontsize=14,rotation=0)
D = text("D", (1,-1.1), color="black", fontsize=14,rotation=0)
F = text("F", (3,-1.1), color="black", fontsize=14,rotation=0)
E = text("E", (2,-1.1), color="black", fontsize=14,rotation=0)
H = text("H", (0.57,1.1), color="red", fontsize=14,rotation=0)
I = text("I", (0.5,-1.08), color="red", fontsize=14,rotation=0)
G = text("G", (0.57,0.7), color="blue", fontsize=14,rotation=0)
K = text("K", (0.57,-0.7), color="blue", fontsize=14,rotation=0)
Q= text("$30^o$", (0.2,0.8), color="red", fontsize=14,rotation=0)
O = text("O", (-1.1,-0.1), color="black", fontsize=14,rotation=0)
J = text("J", (1.1,-0.1), color="black", fontsize=14,rotation=0)
ce=circle((0,0),r,color="red")
pp = polygon(((-1,-1),(-1,1),(1,1),(1,-1)), color="lightcyan")
show(pp+ce+p+q+l+l1+l2+l3+l4+l5+l6+l7+a1+A+B+C+D+E+F+G+H+I+K+Q+O+J,xmin=-2,
xmax=3,ymin=-2,ymax=2,gridlines="minor",gridlinesstyle=dict(color="green",
linestyle="-",alpha=0.3),frame=True,figsize=10)
# Out:
# Graphics object consisting of 26 graphics primitives

# %%
show(pp+ce+p+q+l+l1+l2+l3+l4+l5+l6+l7+F+H+I,xmin=-2,
xmax=3,ymin=-2,ymax=2,gridlines="minor",
gridlinesstyle=dict(color="green",
linestyle="-",alpha=0.3),frame=True,figsize=5)
# Out:
# Graphics object consisting of 15 graphics primitives

# %% [markdown]
# ###### Deuxième partie : construction géométrique de Pi
#
# Soit FH = Pi, on prolonge FH en M tel que HM = 1 (unité)

# %%
Tl= text("L",(0.0,1.9),fontsize=14,color="red")
Th= text("H",(0.0,-0.2),fontsize=14,color="red")
Tp= text("P",(-1.77,1.9),fontsize=14,color="red")
Tn= text("N",(-1.77,-0.2),fontsize=14,color="red")
Tm= text("M",(-1.1,0.1),fontsize=14,color="blue")
lf=line(((0,1.77),(3,0)), color="red",thickness=1/2)
lh=line(((0.0,1.77),(0,0)), color="red",thickness=1.50)
lp=line(((-1.77,1.77),(0,1.77)), color="red",thickness=1.50)
ln=line(((-1.77,0),(0,0)), color="red",thickness=1.50)
pn=line(((-1.77,1.77),(-1.77,0)), color="red",thickness=1.50)
ph=line(((-1.77,1.77),(0,0)), color="orange",linestyle="dashed",
        thickness=1.50)
nl=line(((-1.77,0),(0.0,1.77)), color="orange",linestyle="dashed",
        thickness=1.50)
p = point((1.0,0), color="red",pointsize=10, zorder=5)
Q=line(((-1,0),(3,0)), color="black",thickness=1)
a = arc((1,0), 2, angle=pi/6, sector=(-8.70*pi/4,5*pi/6),thickness=1)
a1 = arc((0,0),1 , angle=pi/6,color="black", 
         sector=(-8.65*pi/4,5*pi/6),thickness=1)
a2 = arc((0,0),1 , angle=pi/6,color="black", 
         sector=(-8.65*pi/4,5*pi/6),thickness=1)
c = circle((-0.885,0.885),1,color="violet",zorder=-5,thickness=2)
show(a+Q+p+Tl+a1+lf+lh+Th+Tp+lp+Tn+ln+pn+ph+nl+c+Tm+C+D+E+F, 
     xmin=-1.85,xmax=3,ymin=-0.25,ymax=2.1,
     gridlines="minor",gridlinesstyle=dict(color="green",
                         linestyle="-"),axes=False,frame=True)
# Out:
# Graphics object consisting of 21 graphics primitives

# %% [markdown]
# Soit $Q$ milieu de $MF$
#
# Un arc de cercle $MLF$ (centre $Q$)
#
# Une perpendiculaire  à $HF$ élevée en $H $coupe l’arc de cercle en $L$,
#
# $LH $=$\sqrt \pi$
#
# ###### Démonstration
#
#  Les triangles $MFL$ et $LHM$ sont rectangles et semblables : $LH/HM = FH/LH$
#
# En conséquence :
#
# $LH² = HM *FH, HM = 1$ (unité)
#
# $LH²= FH = pi$
# $LH  = \sqrt \pi$
#
# ###### Conclusion :
#
# La surface du carré $LPNH$ dont le côté est égal à $\sqrt \pi $est proche de la surface égale à $\pi$ du cercle de centre $H$ et de rayon $HM = 1$.

# %%
Tc = text("C", (-0.1,-1.1), color="black", fontsize=14,rotation=0)
Td = text("D", (1,-1.1), color="black", fontsize=14,rotation=0)
Tf= text("F", (3,-0.1), color="blue", fontsize=14,rotation=0)
Te = text("E", (2,-0.1), color="black", fontsize=14,rotation=0)
a3 = arc((1,0), 2,color="orange", angle=2*pi/2,
         sector=(-8*pi/4,6*pi/6),thickness=1)
a4 = arc((2,0), 1,color="orange", angle=2*pi/2, 
         sector=(-8*pi/4,6*pi/6),thickness=1)
show(a+Q+p+Tl+a1+lf+lh+Th+Tp+lp+Tn+ln+pn+ph+nl+c+a3+a4+Tm+Tf, 
     xmin=-1.85,xmax=3,ymin=-2.1,ymax=2.1,gridlines="minor",
     gridlinesstyle=dict(color="green",
                         linestyle="-"),axes=False,frame=True)
# Out:
# Graphics object consisting of 20 graphics primitives

# %%
sqrt(3.14)*2.0
# Out:
# 3.54400902933387

# %%
pp = polygon(((0,0),(0,1.8),(1.8,1.8),(1.8,0)), color="cyan",
             edgecolor="red", thickness=2)
show(a+Q+p+Tl+a1+lf+lh+Th+Tp+lp+Tn+ln+pn+ph+nl+c+a3+a4+Tm+Tf+pp, 
     xmin=-1.85,xmax=3,ymin=-2.1,ymax=2.1,gridlines="minor",
     gridlinesstyle=dict(color="green",
                         linestyle="-"),axes=False,frame=True)
# Out:
# Graphics object consisting of 21 graphics primitives

# %%
po=polygon(((0,0),(0,1),(1,1),(1,0)), color="green",
             edgecolor="red",thickness=2,figsize=2,fontsize=6);po
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var("y")
a = arc((0,0), 2.45, color="black",
        angle=pi/6, sector=(-8.70*pi/4,5*pi/6),thickness=1)
p1 = implicit_plot(x^2+y^2-8, (x,-3,3), (y,-3,3),
                   plot_points=4, zorder=5)
p2 = implicit_plot(x^2+y^2-6, (x,-3,3), (y,-3,3),
                   color="red", zorder=-5,plot_points=300)
show(p1 + p2+a,figsize=4,fontsize=8)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
Tl= text("L",(0.0,1.9),fontsize=14,color="red")
Th= text("H",(0.0,-0.2),fontsize=14,color="red")
Tp= text("P",(-1.77,1.9),fontsize=14,color="red")
Tn= text("N",(-1.77,-0.2),fontsize=14,color="red")
Tm= text("M",(-1.1,0.1),fontsize=14,color="blue")
lf=line(((0,1.77),(3,0)), color="red",thickness=1/2)
lh=line(((0.0,1.77),(0,0)), color="red",thickness=1.50)
lp=line(((-1.77,1.77),(0,1.77)), color="red",thickness=1.50)
ln=line(((-1.77,0),(0,0)), color="red",thickness=1.50)
pn=line(((-1.77,1.77),(-1.77,0)), color="red",thickness=1.50)
ph=line(((-1.77,1.77),(0,0)), color="orange",linestyle="dashed",
        thickness=1.50)
nl=line(((-1.77,0),(0.0,1.77)), color="orange",linestyle="dashed",
        thickness=1.50)
p = point((1.0,0), color="red",pointsize=10, zorder=5)
Q=line(((-1,0),(3,0)), color="black",thickness=1)
a = arc((1,0), 2, angle=pi/6, sector=(-8.70*pi/4,5*pi/6),thickness=1)
a1 = arc((0,0),1 , angle=pi/6,color="black", 
         sector=(-8.65*pi/4,5*pi/6),thickness=1)
a2 = arc((0,0),1 , angle=pi/6,color="black", 
         sector=(-8.65*pi/4,5*pi/6),thickness=1)
c = circle((0,0),1,color="violet",zorder=-5,thickness=2)
show(c,xmin=-1,xmax=1,ymin=-1,ymax=1,
     gridlines="minor",gridlinesstyle=dict(color="green",
                         linestyle="-"),
     axes=False,frame=True,figsize=10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
p = point((1.0,0), color="red",pointsize=10, zorder=5)
cp=line([(-1,-1),(-1,1),(1,1)])
cq=line([(1,1),(1,-1),(-1,-1)]);r=2/sqrt(n(pi))
ci = circle((0,0),r,color="red",zorder=-5,thickness=2)
show(ci+cp+cq,xmin=-1.5,xmax=1.5,ymin=-1.5,
ymax=1.5,gridlines="minor",gridlinesstyle=dict(color="lightgreen",
linestyle="-"),axes=False,frame=True,figsize=10)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
var("y")
def f(x):
    if x<0:
        return sqrt(-x^2-2*x)
    else:
        return -sqrt(-x^2+2*x)
ci = circle((0,0),r,color="red",zorder=-5,thickness=2)
a=plot(f,(x,-2,2),color='black',fill=sqrt(4-x^2),
fillcolor="black",alpha=0.1)
b=plot(f,(x,-2,2),color="red",fill=-sqrt(4-x^2),
fillcolor="red",alpha=0.1)
pc = implicit_plot(x^2+y^2-8, (x,-3,3), (y,-3,3),
plot_points=4, zorder=5)
p1 = polygon(((0,0),(-1,2.5),(1,2.5)),
             color="cyan",alpha=0.3)
p2 = polygon(((0,0),(0.96,2.5),(2.5,1)),
             color="green",alpha=0.3)
p3 = polygon(((0,0),(-2.5,1),(-1,2.5)),
             color="yellow",alpha=0.3)
p4 = polygon(((0,0),(-2.5,-1),(-2.5,1)),
             color="blue",alpha=0.3)
p5 = polygon(((0,0),(-2.5,-1),(-1,-2.5)),
             color="red",alpha=0.3)
p6 = polygon(((0,0),(2.5,1),(2.5,-1)),
             color="violet",alpha=0.3)
p7 = polygon(((0,0),(2.5,-1),(1,-2.5)),
             color="brown",alpha=0.3)
p8 = polygon(((0,0),(1,-2.5),(-1,-2.5)),
             color="black",alpha=0.3)
ic = circle((0,0),2,color="brown",zorder=-5,thickness=2)
cp=line([(-1,-1),(-1,1),(1,1)])
cq=line([(1,1),(1,-1),(-1,-1)]);r=2/sqrt(n(pi))
show(a+b+pc+p1+p2+p3+p4+p5+p6+p7+p8+ci+cp+cq+ic,
figsize=5,fontsize=8,axes=True,frame=True,
 gridlines="minor",gridlinesstyle=dict(color="lightgreen",
linestyle="-",alpha=0.5)   )
# Out:
# Graphics object consisting of 17 graphics primitives

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
