# %%
# %display latex

# %% [markdown]
# Il faut faire la distinction de l'extérieur de $\pi$ qui est un entier et de l'intérieur qui est une décimale.

# %%
var("y")
ar = arc((0,0), 2.45, color="black",angle=pi/6,
sector=(-8.70*pi/4,5*pi/6),thickness=1)
pc = implicit_plot(x^2+y^2-8, (x,-3,3), (y,-3,3),
plot_points=4, zorder=5)
pp = implicit_plot(x^2+y^2-6, (x,-3,3), (y,-3,3),
color="red", zorder=-5,plot_points=300)
show(pc+pp,figsize=4,fontsize=8,gridlines="minor",
gridlinesstyle=dict(color="green",linestyle="-"),
axes=False,frame=True)
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# Donc le tour extérieur du cercle fait 3 et non pas 3.1, si je mesure le cercle à l'intérieur dans ce cas là j'ai 3+1/10=3.1, mais toujours pas l'infini. Le rapport est fini selon la précision qu'on en veut.

# %%
var("y")
O = text("c=3", (-1.9,2.1), 
         color="red", fontsize=8,rotation=40)
O1= text("c=3.1", (-1.3,1.1), 
         color="blue", fontsize=8,rotation=50)
p0=implicit_plot(0.14+(1^2+1^2)+1, (x,-3,3), (y,-3,3),
color="green", zorder=-5,plot_points=300)
pl = implicit_plot(0.3+(x^2+y^2-6),(x,-3,3),(y,-3,3),
color="blue", zorder=-5,plot_points=300)
p2 = implicit_plot(x^2+y^2-6, (x,-3,3), (y,-3,3),
color="red", zorder=-5,plot_points=300)
show(p0+pl+pp+O+O1,figsize=2,fontsize=8,gridlines="minor",
gridlinesstyle=dict(color="green",linestyle="-",alpha=0.2),
axes=False,frame=True)
# Out:
# /home/pi/sage/local/lib/python2.7/site-packages/matplotlib/contour.py:1230: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"
# Graphics object consisting of 5 graphics primitives

# %%
0.14+(1^2+1^2)+1
# Out:
# 3.14000000000000

# %%
3-3.1
# Out:
# -0.100000000000000

# %%
def f(x):
    if x<0:
        return sqrt(-x^2-2*x)
    else:
        return -sqrt(-x^2+2*x)
a=plot(f,(x,-2,2),color='white',fill=sqrt(4-x^2),
fillcolor="black",alpha=0.1)
b=plot(f,(x,-2,2),color="white",fill=-sqrt(4-x^2),
fillcolor="red",alpha=0.1)
show(a+b+pp+pc,figsize=4,fontsize=8,
axes=True,frame=True)
# Out:
# Graphics object consisting of 6 graphics primitives

# %%
c0 = circle((-1,0.9),2, color="red",fill="red",alpha=0.7)
co = circle((-1,0.9),0.1, color="white",fill="white")
cp = circle((1,0.8),0.1, color="white",fill="white")
c1 = circle((1,0.8),2, color="blue",fill="blue",alpha=0.7)
c2 = circle((0.0,-0.8),2, color="green",fill="green",alpha=0.7)
cb=circle((0.0,-0.8),0.1, color="white",fill="white",alpha=0.7)
show(c0+c1+c2+cb+co+cp,figsize=4,fontsize=8,axes=True,frame=True)
# Out:
# Graphics object consisting of 6 graphics primitives

# %%
p1 = polygon(((0,0),(-1,2.5),(1,2.5)),
             color="cyan",alpha=0.9)
p2 = polygon(((0,0),(0.96,2.5),(2.5,1)),
             color="green",alpha=0.9)
p3 = polygon(((0,0),(-2.5,1),(-1,2.5)),
             color="yellow",alpha=0.9)
p4 = polygon(((0,0),(-2.5,-1),(-2.5,1)),
             color="blue",alpha=0.3)
p5 = polygon(((0,0),(-2.5,-1),(-1,-2.5)),
             color="red",alpha=0.9)
p6 = polygon(((0,0),(2.5,1),(2.5,-1)),
             color="violet",alpha=0.9)
p7 = polygon(((0,0),(2.5,-1),(1,-2.5)),
             color="brown",alpha=0.9)
p8 = polygon(((0,0),(1,-2.5),(-1,-2.5)),
             color="orange",alpha=0.9)
show(p2+p3,figsize=4,fontsize=8,
axes=True,frame=True)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
p2 = polygon(((0,0),(0.96,2.5),(2.5,1)),
             color="green",alpha=0.3)
p3 = polygon(((0,0),(-1,2.5),(1,2.5)),
             color="blue",alpha=0.3)
show(a+b+p1,figsize=4,fontsize=8,
axes=True,frame=True)
# Out:
# Graphics object consisting of 5 graphics primitives

# %%
p4 = polygon(((0,0),(-2.5,1),(-1,2.5)),
             color="red",alpha=0.3)
show(a+b+pp+p1+p2+p3+p4,figsize=4,fontsize=8,
axes=True,frame=True)
# Out:
# Graphics object consisting of 9 graphics primitives

# %%
p5 = polygon(((0,0),(-2.5,1),(-1,2.5)),
             color="yellow",alpha=0.3)
show(a+b+p2+p3+p4+p5,figsize=4,fontsize=8,
axes=True,frame=True)
# Out:
# Graphics object consisting of 8 graphics primitives

# %%
p1 = polygon(((0,0),(-1,2.5),(1,2.5)),
             color="cyan",alpha=0.9)
p2 = polygon(((0,0),(0.96,2.5),(2.5,1)),
             color="green",alpha=0.9)
p3 = polygon(((0,0),(-2.5,1),(-1,2.5)),
             color="yellow",alpha=0.9)
p4 = polygon(((0,0),(-2.5,-1),(-2.5,1)),
             color="blue",alpha=0.5)
p5 = polygon(((0,0),(-2.5,-1),(-1,-2.5)),
             color="red",alpha=0.9)
p6 = polygon(((0,0),(2.5,1),(2.5,-1)),
             color="violet",alpha=0.9)
p7 = polygon(((0,0),(2.5,-1),(1,-2.5)),
             color="brown",alpha=0.9)
p8 = polygon(((0,0),(1,-2.5),(-1,-2.5)),
             color="orange",alpha=0.9)
show(pc+p1+p2+p3+p4+p5+p6+p7+p8,figsize=4,
fontsize=8,axes=True,frame=True)
# Out:
# Graphics object consisting of 9 graphics primitives

# %%
def f(x):
    if x<0:
        return sqrt(-x^2-2*x)
    else:
        return -sqrt(-x^2+2*x)
a=plot(f,(x,-2,2),color='white',fill=sqrt(4-x^2),
fillcolor="black",alpha=1)
b=plot(f,(x,-2,2),color="white",fill=-sqrt(4-x^2),
fillcolor="red",alpha=1)
p1 = polygon(((0,0),(-1,2.5),(1,2.5)),
             color="cyan",alpha=0.3)
p2 = polygon(((0,0),(1,2.5),(2.5,1)),
             color="green",alpha=0.3)
p3 = polygon(((0,0),(-2.5,1),(-1,2.5)),
             color="yellow",alpha=0.3)
p4 = polygon(((0,0),(-2.5,-1),(-2.5,1)),
             color="blue",alpha=0.3)
p5 = polygon(((0,0),(-2.5,-1),(-1,-2.5)),
             color="red",alpha=0.3)
p6 = polygon(((0,0),(2.5,1),(2.5,-1)),
             color="violet",alpha=0.3)
p7 = polygon(((0,0),(2.5,-1),(1,-2.5)),
             color="brown",alpha=0.3)
p8 = polygon(((0,0),(1,-2.5),(-1,-2.5)),
             color="orange",alpha=0.3)
r=2/sqrt(n(pi))
cp=line([(-1,-1),(-1,1),(1,1)])
cq=line([(1,1),(1,-1),(-1,-1)])
c0=circle((0,0),r,color="red",alpha=0.5)
c1=circle((-1,0),1,color="white",alpha=0.5)
c2=circle((1,0),1,color="white",alpha=0.5)
c3=circle((0,-1),1,color="white",alpha=0.5)
c4=circle((0,1),1,color="white",alpha=0.5)
show(a+b+pc+p1+p2+p3+p4+p5+p6+p7+p8+c1+cp+cq+c2+c3+c4+c0,
figsize=10,fontsize=8,axes=True,frame=True,gridlines="minor",
gridlinesstyle=dict(color="lightgrey",linestyle="-",alpha=0.3)  )
# Out:
# Graphics object consisting of 20 graphics primitives

# %% [markdown]
# Le ba gua c'est 8 notes et 8 couleurs 3 paires 3 impaires - noir et + blanc
#
# Les lunules représentent les 4 trimestres.

# %%
show("Rapport = 377/365 =", 120*n(pi)/365.6)
# Out:
# 'Rapport = 377/365 =' 1.03115732612356

# %%
show("Rapport = 377/360 =", 120*n(pi)/360)
# Out:
# 'Rapport = 377/360 =' 1.04719755119660

# %%
ga, t, tt, x, xx, v,c = SR.var("ga t c tt x xx v")

# %%
eq1 = tt == ga * (t - v*x/c^2);show(eq1)
eq2 = xx == ga * (x - v*t);show(eq2)
# Out:
# c == ga*(t - tt*xx/v^2)
# x == -(t*xx - tt)*ga

# %%
solve([eq1, eq2], t, x)
# Out:
# [[t == (c*v^2 + x*xx)/(ga*v^2 - ga*xx^2), tt == (c*v^2*xx + v^2*x)/(ga*v^2 - ga*xx^2)]]

# %%
reset()
gamma, t_0,t,x_0,x, v,c = SR.var("gamma t_0 x_0 t c  x  v")
eq3 = t_0 == gamma * (t - v*x/c^2);show(eq3)
eq4 = x_0 == gamma * (x - v*t);show(eq4)
solve([eq3, eq4], t, x)
# Out:
# t_0 == gamma*(x_0 - c*x/v^2)
# t == -(x*x_0 - c)*gamma
# [[x_0 == (t_0*v^2 + t*x)/(gamma*v^2 - gamma*x^2), c == (t_0*v^2*x + t*v^2)/(gamma*v^2 - gamma*x^2)]]

# %%
var("s_v s_c")
solve((v*x)^2/(c^2*t^2),x)
# Out:
# [c == 0]

# %%
sc=s_c==(v*x)^2/(c^2*t^2);show(sc,"=0")
# Out:
# s_c == c^2*x^2/(v^2*x_0^2) '=0'

# %%
solve((c^2*t^2)/(v*x)^2,c)
# Out:
# [v == 0]

# %%
sv=s_v==((c^2*t^2)/(v*x)^2);show(sv,"=0")
# Out:
# s_v == v^2*x_0^2/(c^2*x^2) '=0'

# %%
var("y")
pc = implicit_plot(x^2+y^2-8, (x,-3,3), (y,-3,3),
plot_points=4, zorder=5)
p1 = polygon(((0,0),(-1,2.5),(1,2.5)),
             color="cyan",alpha=0.9)
p2 = polygon(((0,0),(0.96,2.5),(2.5,1)),
             color="violet",alpha=0.9)
p3 = polygon(((0,0),(-2.5,1),(-1,2.5)),
             color="yellow",alpha=0.9)
p4 = polygon(((0,0),(-2.5,-1),(-2.5,1)),
             color="",alpha=0.5)
p5 = polygon(((0,0),(-2.5,-1),(-1,-2.5)),
             color="red",alpha=0.9)
p6 = polygon(((0,0),(2.5,1),(2.5,-1)),
             color="white",alpha=1)
p7 = polygon(((0,0),(2.5,-1),(1,-2.5)),
             color="lightgreen",alpha=1)
p8 = polygon(((0,0),(1,-2.5),(-1,-2.5)),
             color="blue",alpha=0.9)
show(pc+p1+p2+p3+p4+p5+p6+p7+p8,figsize=4,
fontsize=8,axes=True,frame=True)
# Out:
# Graphics object consisting of 9 graphics primitives
